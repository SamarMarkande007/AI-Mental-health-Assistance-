# %%
pip install numpy==1.26.4
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\users\sahaj\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

import shap

# %%
df = pd.read_excel("annualsupplementarytablemar23correction.xlsx")

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [A correction has been made to the Urban and Rural estimates and the unweighted bases in Tables S3, S16 and S28. This was due to linking errors.
# We have corrected these errors. You can see all previous versions of this data on the previous versions page.
#
# We apologise for any inconvenience - first published 20th July 2023.]
# Index: []

# %%
print(df.head())

print(df.columns)

print(df.info())
# Out:
# Empty DataFrame
# Columns: [A correction has been made to the Urban and Rural estimates and the unweighted bases in Tables S3, S16 and S28. This was due to linking errors.
# We have corrected these errors. You can see all previous versions of this data on the previous versions page.
#
# We apologise for any inconvenience - first published 20th July 2023.]
# Index: []
# Index(['A correction has been made to the Urban and Rural estimates and the unweighted bases in Tables S3, S16 and S28. This was due to linking errors.  \nWe have corrected these errors. You can see all previous versions of this data on the previous versions page. \n\nWe apologise for any inconvenience - first published 20th July 2023.'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                  --------------  -----
#  0   A correction has been made to the Urban and Rural estimates and the unweighted bases in Tables S3, S16 and S28. This was due to linking errors.
# We have corrected these errors. You can see all previous versions of this data on the previous versions page.
#
# We apologise for any inconvenience - first published 20th July 2023.  0 non-null      object
# dtypes: object(1)
# memory usage: 132.0+ bytes
# None

# %%
df = df.dropna()

# %%
label_encoder = LabelEncoder()

categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\sahaj\anaconda3\lib\site-packages (0.51.0)
# Collecting numpy>=2 (from shap)
#   Using cached numpy-2.4.5-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: scipy in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (0.61.2)
# Requirement already satisfied: llvmlite in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (0.44.0)
# Requirement already satisfied: cloudpickle in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: typing-extensions in c:\users\sahaj\anaconda3\lib\site-packages (from shap) (4.14.0)
# Requirement already satisfied: colorama in c:\users\sahaj\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sahaj\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sahaj\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sahaj\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sahaj\anaconda3\lib\site-packages (from scikit-learn->shap) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sahaj\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\sahaj\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\sahaj\anaconda3\Lib\site-packages\~%mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\sahaj\anaconda3\Lib\site-packages\~0mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.5.1 which is incompatible.
# ydata-profiling 4.16.1 requires numba<=0.61,>=0.56.0, but you have numba 0.61.2 which is incompatible.
# ydata-profiling 4.16.1 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# ydata-profiling 4.16.1 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.
